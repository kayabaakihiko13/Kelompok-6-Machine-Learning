# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from model_random import random,seed

# %%
def pearson_corr(x, y):
    n = len(x)
    mean_x = sum(x) / n
    mean_y = sum(y) / n
    S_xy = sum([(x[i]-mean_x)*(y[i]-mean_y) for i in range(n)])
    S_xx = sum([(x[i]-mean_x)**2 for i in range(n)])
    S_yy = sum([(y[i]-mean_y)**2 for i in range(n)])
    r = S_xy / (S_xx ** 0.5 * S_yy ** 0.5)
    return r
pearson_corr(x,y)
# Out:
# 0.9439041887377126

# %%
seed(0)
y=np.array([i*0.01+np.random.randn() for i in range(1000)])
x=np.array([i*0.1 for i in range(1000)])
# plt.scatter(x,y)
sns.scatterplot(x=x,y=y)
# Out:
# <AxesSubplot: >

# %%
from static import LinearRegression,r2_score
from model_random import random
model=LinearRegression()
X=x.reshape(-1,1)
Y=y.reshape(-1,1)
model.fit_transforms(X,Y)
y_pred=model.predict(X)
plt.scatter(X,Y)
plt.plot(X,y_pred,c='r')

# %%
r2_score(Y,y_pred)
r2_score(Y,X)
# Out:
# -276.3373711104165

# %%
from sklearn.metrics import r2_score
r2_score(Y,y_pred)
# Out:
# 0.8909551175165973

# %% [markdown]
# KNN Regessor

# %%
from static import Knn


model=Knn(3)
model.fit(X,Y)
new_data=model.predict([random(),random()])
r2_score(Y,new_data)
# Out:
# 0.9255780560469916
